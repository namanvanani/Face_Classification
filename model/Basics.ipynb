# %%
import numpy as np
import cv2
import matplotlib 
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./test_image/maria-1.jpg')
img.shape
# Out:
# (212, 238, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (212, 238)

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# # Detect Face and Eyes using HAAR cascade

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
eyse = eye_cascade.detectMultiScale(gray)
faces # it will returns the dimensions of face...[x,y,width,height]
# Out:
# array([[56, 34, 93, 93]])

# %%
(x,y,z,w) = faces[0]
x,y,z,w
# Out:
# (56, 34, 93, 93)

# %%
face_image = cv2.rectangle(gray, (x,y), (x+z,y+w), (255,0,0), 2)
only_face = gray[y:y+w, x:x+z]
plt.imshow(face_image, cmap='gray')

# %%
eyes = eye_cascade.detectMultiScale(only_face)
eyes
# Out:
# array([[52, 24, 22, 22],
#        [18, 28, 23, 23]])

# %%
cv2.destroyAllWindows()
for (ex, ey, ew, eh) in eyes:
    cv2.rectangle(only_face, (ex, ey), (ex+ew, ey+eh), (0,255,0),2)
    
plt.imshow(gray,cmap='gray')
